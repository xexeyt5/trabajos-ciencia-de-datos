# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

import warnings
warnings.filterwarnings("ignore")

# %%
cwd = os.getcwd()

os.chdir('/home/xexeyt/Desktop/trabajos/')

population = pd.read_csv('employee_salary.csv', header=0, sep=',')
population
# Out:
#       Department                               Department Name  \
# 0            BOA                   Board of Appeals Department
# 1            BOA                   Board of Appeals Department
# 2            BOA                   Board of Appeals Department
# 3            BOE                            Board of Elections
# 4            BOE                            Board of Elections
# ...          ...                                           ...
# 10100        SHF                              Sheriff's Office
# 10101        ZAH  Office of Zoning and Administrative Hearings
# 10102        ZAH  Office of Zoning and Administrative Hearings
# 10103        ZAH  Office of Zoning and Administrative Hearings
# 10104        ZAH  Office of Zoning and Administrative Hearings
#
#                                            Division Gender  Base Salary  \
# 0                         Board of Appeals Division      F     78902.00
# ...

# %%
population_base_salary = population['Base Salary']

sns.distplot(population_base_salary)
plt.xlabel('population_base_salary')
plt.ylabel('population_base_salary')
# Out:
# Text(0, 0.5, 'population_base_salary')

# %%
mean = []

def calc_sample_mean(data, samble_size, no_sample_menas):
    for i in range(no_sample_menas):
        sample = data.sample(n=samble_size)
        sample_mean = sample.mean()
        mean.append(sample_mean)
    return(mean)

# %%
mean_2 = calc_sample_mean(data=population_base_salary, samble_size=2, no_sample_menas=500)

sns.distplot(mean_2, color='b')
plt.xlabel('sample base salary (sample size =2)')
plt.ylabel('probability density')
# Out:
# Text(0, 0.5, 'probability density')

# %%
mean_3 = calc_sample_mean(data=population_base_salary, samble_size=5, no_sample_menas=500)

sns.distplot(mean_3, color='r')
plt.xlabel('sample base salary (sample size =5)')
plt.ylabel('probability density')
# Out:
# Text(0, 0.5, 'probability density')

# %%
mean_4 = calc_sample_mean(data=population_base_salary, samble_size=10, no_sample_menas=500)

sns.distplot(mean_4, color='g')
plt.xlabel('sample base salary (sample size =10)')
plt.ylabel('probability density')
# Out:
# Text(0, 0.5, 'probability density')

# %%
mean_5 = calc_sample_mean(data=population_base_salary, samble_size=20, no_sample_menas=500)

sns.distplot(mean_5, color='black')
plt.xlabel('sample base salary (sample size =20)')
plt.ylabel('probability density')
# Out:
# Text(0, 0.5, 'probability density')

# %%
mean_6 = calc_sample_mean(data=population_base_salary, samble_size=30, no_sample_menas=500)

sns.distplot(mean_6, color='red')
plt.xlabel('sample base salary (sample size =30)')
plt.ylabel('probability density')
# Out:
# Text(0, 0.5, 'probability density')

# %%
mean_7 = calc_sample_mean(data=population_base_salary, samble_size=50, no_sample_menas=500)

sns.distplot(mean_7, color='purple')
plt.xlabel('sample base salary (sample size =50)')
plt.ylabel('probability density')
# Out:
# Text(0, 0.5, 'probability density')

# %%
import pandas as pd
import os
df = pd.read_csv('housing.csv', header = 0,sep =',')
df.head(4)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import pandas as pd
import warnings

#ser warnings to ignore
warnings.filterwarnings("ignore")

import os

# %%
df[['housing_median_age', 'total_rooms']].corr()
# Out:
#                     housing_median_age  total_rooms
# housing_median_age            1.000000    -0.361262
# total_rooms                  -0.361262     1.000000

# %%
corr = df[['housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households']].corr( method='spearman')

# %%
import pandas as pd
import seaborn as sns
import warnings

# %%
sns.heatmap(corr, cmap='Blues_r', annot=True)
# Out:
# <Axes: >

# %%
corr = df[['longitude',	'latitude']].corr( method='pearson')


sns.heatmap(corr, cmap='Blues_r', annot=True)
# Out:
# <Axes: >

# %%
corr = df[['longitude',	'latitude']].corr( method='spearman')


sns.heatmap(corr, cmap='Blues_r', annot=True)
# Out:
# <Axes: >
