# %%
import pandas as pd
df = pd.read_csv('Productos.csv',sep=',',header=0)
df
# Out:
#     idP                  nombre          tipo  precio_compra  precio_venta
# 0     1   Electrónica Producto1   Electrónica          29.73         38.76
# 1     2          Ropa Producto1          Ropa          36.19         42.68
# 2     3  Alimentación Producto1  Alimentación          86.68        123.02
# 3     4         Hogar Producto1         Hogar          99.36        111.01
# 4     5       Deporte Producto1       Deporte          35.01         50.94
# 5     6   Electrónica Producto2   Electrónica          65.25         95.65
# 6     7          Ropa Producto2          Ropa          85.82        105.32
# 7     8  Alimentación Producto2  Alimentación          39.76         55.91
# 8     9         Hogar Producto2         Hogar          28.83         37.53
# 9    10       Deporte Producto2       Deporte          90.17        130.06
# 10   11   Electrónica Producto3   Electrónica          92.28        126.01
# ...
